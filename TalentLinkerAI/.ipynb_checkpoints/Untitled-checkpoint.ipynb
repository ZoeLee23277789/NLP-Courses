# %%
import scrapy
from scrapy.crawler import CrawlerProcess


class IndeedJobSpider(scrapy.Spider):
    name = "indeed_jobs"

    def start_requests(self):
        url = "https://www.indeed.com/jobs?q=software+engineer&l=California"
        headers = {
            "User-Agent": "Zoe/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36",
            "Accept-Language": "en-US,en;q=0.9",
            "Referer": "https://www.google.com/",
        }
        yield scrapy.Request(url=url, headers=headers, callback=self.parse)

    def parse(self, response):
        print(response.text[:500])  # 打印返回的 HTML 內容
        yield {"status": "success"}  # 確保輸出內容

# 更新 Scrapy 配置
process = CrawlerProcess(settings={
    "USER_AGENT": "Zoe/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36",
    "ROBOTSTXT_OBEY": False,
    "HTTPPROXY_ENABLED": True,
    "DOWNLOADER_MIDDLEWARES": {
        'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware': 1,
    },
    "LOG_LEVEL": "INFO",
    "PROXY": "http://scraperapi:21e877d5890d9ebf3a536f91af61d983@proxy-server.scraperapi.com:8001",
})

process.crawl(IndeedJobSpider)
process.start()
# Out:
# 2024-11-22 20:47:20 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# 2024-11-22 20:47:20 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.11.7, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.10.0, Python 3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.3, Platform Windows-10-10.0.26100-SP0
# 2024-11-22 20:47:20 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-11-22 20:47:20 [py.warnings] WARNING: C:\Users\USER\anaconda3\envs\pytorch\lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# ...

# %%
import scrapy
from scrapy.crawler import CrawlerProcess
from scrapy_selenium import SeleniumRequest

class IndeedJobSpider(scrapy.Spider):
    name = "indeed_jobs"

    def start_requests(self):
        url = "https://www.indeed.com/jobs?q=software+engineer&l=California"
        yield SeleniumRequest(url=url, callback=self.parse)

    def parse(self, response):
        print(response.text[:500])
        
process.crawl(IndeedJobSpider)
process.start()
