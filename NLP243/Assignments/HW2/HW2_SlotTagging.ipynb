# %%
import pandas as pd
import matplotlib.pyplot as plt

# 加載數據
train_df = pd.read_csv('./hw2_train.csv')

# 提取所有標籤
all_tags = train_df['IOB Slot tags'].str.split().sum()

# 計算各標籤的出現次數
tag_counts = pd.Series(all_tags).value_counts(normalize=True) * 100  # 轉換為百分比

# 繪製各標籤的佔比
plt.figure(figsize=(10, 6))
tag_counts.plot(kind='bar')
plt.xlabel('Tags')
plt.ylabel('Percentage (%)')
plt.title('Tag Distribution in hw2_train.csv')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from transformers import BertTokenizer, BertModel
from sklearn.model_selection import train_test_split
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import TensorDataset, DataLoader
from seqeval.metrics import classification_report, f1_score, precision_score, recall_score
import warnings
warnings.filterwarnings("ignore")

# 檢查是否有 GPU 可用
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("使用的設備:", device)

# 加載數據
train_df = pd.read_csv('hw2_train.csv')
print(train_df)

# 初始化 BERT Tokenizer 和 Model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
bert_model = BertModel.from_pretrained("bert-base-uncased").to(device)

# 設定最大序列長度
MAX_LENGTH = 128  # 可根據需要調整

# 調整 BERT 編碼函數
def encode_texts(texts, tokenizer, bert_model, device, max_length=MAX_LENGTH):
    inputs = tokenizer(
        texts, padding="max_length", truncation=True, max_length=max_length, return_tensors="pt"
    ).to(device)
    with torch.no_grad():
        outputs = bert_model(**inputs)
    embeddings = outputs.last_hidden_state  # Shape: (batch_size, max_length, hidden_dim)
    return embeddings, inputs["attention_mask"].sum(dim=1)

# 提取句子的 BERT 嵌入
utterances = train_df['utterances'].tolist()
embeddings, sequence_lengths = encode_texts(utterances, tokenizer, bert_model, device)

# 構建標籤映射字典
unique_labels = set(label for tags in train_df['IOB Slot tags'] for label in tags.split())
label_to_index = {label: idx for idx, label in enumerate(unique_labels)}
idx_to_label = {idx: label for label, idx in label_to_index.items()}
print("idx_to_label = " , idx_to_label)
# 將標籤轉換為數字格式並填充到 BERT 輸出的 max_length 長度
labels = train_df['IOB Slot tags'].apply(lambda x: [label_to_index[label] for label in x.split()])
labels_padded = pad_sequence(
    [torch.tensor(label + [label_to_index["O"]] * (MAX_LENGTH - len(label))) for label in labels], 
    batch_first=True
).to(device)

# 最後確認 BERT 嵌入與標籤的形狀一致
assert embeddings.shape[1] == labels_padded.shape[1], "BERT 輸出序列長度和標籤序列長度不匹配"
X_train, X_test, y_train, y_test = train_test_split(embeddings, labels_padded, test_size=0.2, random_state=42)

# 創建數據集和數據加載器
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# 定義 LSTM 模型來處理 BERT 輸出
# class SlotTaggingModel(nn.Module):
#     def __init__(self, bert_hidden_dim, hidden_dim, output_dim):
#         super(SlotTaggingModel, self).__init__()
#         self.lstm = nn.LSTM(bert_hidden_dim, hidden_dim, batch_first=True)
#         self.fc = nn.Linear(hidden_dim, output_dim)
    
#     def forward(self, x):
#         lstm_out, _ = self.lstm(x)
#         output = self.fc(lstm_out)
#         return output

class SlotTaggingModel(nn.Module):
    def __init__(self, bert_hidden_dim, hidden_dim, output_dim, dropout_prob=0.5):
        super(SlotTaggingModel, self).__init__()
        self.lstm = nn.LSTM(bert_hidden_dim, hidden_dim, batch_first=True)
        self.dropout = nn.Dropout(dropout_prob)  # 新增Dropout層
        self.fc = nn.Linear(hidden_dim, output_dim)
    
    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        lstm_out = self.dropout(lstm_out)  # 在LSTM輸出後應用Dropout
        output = self.fc(lstm_out)
        return output


# 初始化模型
bert_hidden_dim = embeddings.shape[2]
hidden_dim = 128
output_dim = len(label_to_index)
model = SlotTaggingModel(bert_hidden_dim, hidden_dim, output_dim).to(device)
# 印出所有可預測的標籤
print("模型可以預測的 Tags:")
for idx, label in idx_to_label.items():
    print(f"Index: {idx}, Tag: {label}")
# 定義損失函數和優化器
# criterion = nn.CrossEntropyLoss(ignore_index=label_to_index["O"])
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 訓練模型
def train_model(model, train_loader, criterion, optimizer, device):
    model.train()
    total_loss = 0.0
    for batch_x, batch_y in train_loader:
        batch_x, batch_y = batch_x.to(device), batch_y.to(device)
        assert batch_x.shape[1] == batch_y.shape[1], "輸出序列長度和標籤序列長度不匹配"

        optimizer.zero_grad()
        outputs = model(batch_x).view(-1, output_dim)
        batch_y = batch_y.view(-1)
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)

# 調整後的評估模型
def evaluate_model(model, test_loader, criterion, device, idx_to_label):
    model.eval()
    total_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch_x, batch_y in test_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            assert batch_x.shape[1] == batch_y.shape[1], "輸出序列長度和標籤序列長度不匹配"

            outputs = model(batch_x).view(-1, output_dim)
            batch_y = batch_y.view(-1)
            loss = criterion(outputs, batch_y)
            total_loss += loss.item()

            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            labels = batch_y.cpu().numpy()

            # 將 index 轉換為對應的標籤
            preds = [idx_to_label[idx] for idx in preds]
            labels = [idx_to_label[idx] for idx in labels]

            all_preds.append(preds)
            all_labels.append(labels)

    avg_loss = total_loss / len(test_loader)
    
    # 使用 seqeval 計算精確度、召回率和 F1 分數
    report = classification_report(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds)
    recall = recall_score(all_labels, all_preds)

    print(f"Test Loss: {avg_loss:.4f}")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}")
    print("Classification Report:\n", report)

    return avg_loss, precision, recall, f1

# 訓練和評估過程
num_epochs = 500
for epoch in range(num_epochs):
    train_loss = train_model(model, train_loader, criterion, optimizer, device)
    test_loss, precision, recall, f1 = evaluate_model(model, test_loader, criterion, device, idx_to_label)
    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}')
# Out:
# 使用的設備: cuda
#         ID                                         utterances  \
# 0        1               who plays luke on star wars new hope
# 1        2                     show credits for the godfather
# 2        3             who was the main actor in the exorcist
# 3        4  find the female actress from the movie she 's ...
# 4        5                    who played dory on finding nemo
# ...    ...                                                ...
# 2307  2308               what was the revenue for toy story 3
# 2308  2309                                dark knight revenue
# 2309  2310               how much did the dark night generate
# 2310  2311                 can i see the lion king 's revenue
# 2311  2312        can i see what the lion king 's revenue was
#
#                                       IOB Slot tags
# 0      O O B_char O B_movie I_movie I_movie I_movie
# 1                             O O O B_movie I_movie
# 2                       O O O O O O B_movie I_movie
# 3     O O O O O O O B_movie I_movie I_movie I_movie
# 4                      O O B_char O B_movie I_movie
# ...                                             ...
# 2307              O O O O O B_movie I_movie I_movie
# 2308                              B_movie I_movie O
# 2309                O O O B_movie I_movie I_movie O
# 2310              O O O B_movie I_movie I_movie O O
# 2311          O O O O B_movie I_movie I_movie O O O
#
# [2312 rows x 3 columns]
# idx_to_label =  {0: 'B_cast', 1: 'B_char', 2: 'I_subject', 3: 'B_release_year', 4: 'O', 5: 'I-movie', 6: 'I_release_year', 7: 'B_country', 8: 'I_char', 9: 'I_producer', 10: 'B_movie', 11: 'I_genre', 12: 'B_subject', 13: 'I_mpaa_rating', 14: 'I_country', 15: 'B_location', 16: 'I_cast', 17: 'I_language', 18: 'I_person', 19: 'B_genre', 20: 'B_person', 21: 'B_mpaa_rating', 22: 'B_language', 23: 'B_director', 24: 'B_producer', 25: 'O¬¥O', 26: 'I_director', 27: 'I_movie'}
# 模型可以預測的 Tags:
# Index: 0, Tag: B_cast
# Index: 1, Tag: B_char
# Index: 2, Tag: I_subject
# Index: 3, Tag: B_release_year
# Index: 4, Tag: O
# Index: 5, Tag: I-movie
# Index: 6, Tag: I_release_year
# Index: 7, Tag: B_country
# Index: 8, Tag: I_char
# Index: 9, Tag: I_producer
# Index: 10, Tag: B_movie
# Index: 11, Tag: I_genre
# Index: 12, Tag: B_subject
# Index: 13, Tag: I_mpaa_rating
# Index: 14, Tag: I_country
# Index: 15, Tag: B_location
# Index: 16, Tag: I_cast
# Index: 17, Tag: I_language
# Index: 18, Tag: I_person
# Index: 19, Tag: B_genre
# Index: 20, Tag: B_person
# Index: 21, Tag: B_mpaa_rating
# Index: 22, Tag: B_language
# Index: 23, Tag: B_director
# Index: 24, Tag: B_producer
# Index: 25, Tag: O¬¥O
# Index: 26, Tag: I_director
# Index: 27, Tag: I_movie
# Test Loss: 0.0908
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.00      0.00      0.00        18
#        _char       0.00      0.00      0.00         1
#     _country       0.00      0.00      0.00        23
#    _director       0.00      0.00      0.00        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.00      0.00      0.00        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.00      0.00      0.00       217
# _mpaa_rating       0.00      0.00      0.00        32
#      _person       0.00      0.00      0.00        39
#    _producer       0.00      0.00      0.00        38
#     _subject       0.00      0.00      0.00        21
#
#    micro avg       0.00      0.00      0.00       455
#    macro avg       0.00      0.00      0.00       455
# weighted avg       0.00      0.00      0.00       455
#
# Epoch 1/500, Train Loss: 0.4124, Test Loss: 0.0908
# Test Loss: 0.0618
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.00      0.00      0.00        18
#        _char       0.00      0.00      0.00         1
#     _country       0.00      0.00      0.00        23
#    _director       0.00      0.00      0.00        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.00      0.00      0.00        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.00      0.00      0.00       217
# _mpaa_rating       0.00      0.00      0.00        32
#      _person       0.00      0.00      0.00        39
#    _producer       0.00      0.00      0.00        38
#     _subject       0.00      0.00      0.00        21
#
#    micro avg       0.00      0.00      0.00       455
#    macro avg       0.00      0.00      0.00       455
# weighted avg       0.00      0.00      0.00       455
#
# Epoch 2/500, Train Loss: 0.0766, Test Loss: 0.0618
# Test Loss: 0.0536
# Precision: 0.0000, Recall: 0.0000, F1 Score: 0.0000
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.00      0.00      0.00        18
#        _char       0.00      0.00      0.00         1
#     _country       0.00      0.00      0.00        23
#    _director       0.00      0.00      0.00        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.00      0.00      0.00        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.00      0.00      0.00       217
# _mpaa_rating       0.00      0.00      0.00        32
#      _person       0.00      0.00      0.00        39
#    _producer       0.00      0.00      0.00        38
#     _subject       0.00      0.00      0.00        21
#
#    micro avg       0.00      0.00      0.00       455
#    macro avg       0.00      0.00      0.00       455
# weighted avg       0.00      0.00      0.00       455
#
# Epoch 3/500, Train Loss: 0.0612, Test Loss: 0.0536
# Test Loss: 0.0463
# Precision: 0.0941, Recall: 0.0176, F1 Score: 0.0296
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.00      0.00      0.00        18
#        _char       0.00      0.00      0.00         1
#     _country       0.00      0.00      0.00        23
#    _director       0.00      0.00      0.00        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.00      0.00      0.00        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.09      0.04      0.05       217
# _mpaa_rating       0.00      0.00      0.00        32
#      _person       0.00      0.00      0.00        39
#    _producer       0.00      0.00      0.00        38
#     _subject       0.00      0.00      0.00        21
#
#    micro avg       0.09      0.02      0.03       455
#    macro avg       0.01      0.00      0.00       455
# weighted avg       0.04      0.02      0.03       455
#
# Epoch 4/500, Train Loss: 0.0530, Test Loss: 0.0463
# Test Loss: 0.0404
# Precision: 0.4167, Recall: 0.1319, F1 Score: 0.2003
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.00      0.00      0.00        18
#        _char       0.00      0.00      0.00         1
#     _country       0.00      0.00      0.00        23
#    _director       0.00      0.00      0.00        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.00      0.00      0.00        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.42      0.28      0.33       217
# _mpaa_rating       0.00      0.00      0.00        32
#      _person       0.00      0.00      0.00        39
#    _producer       0.00      0.00      0.00        38
#     _subject       0.00      0.00      0.00        21
#
#    micro avg       0.42      0.13      0.20       455
#    macro avg       0.03      0.02      0.03       455
# weighted avg       0.20      0.13      0.16       455
#
# Epoch 5/500, Train Loss: 0.0459, Test Loss: 0.0404
# Test Loss: 0.0367
# Precision: 0.4730, Recall: 0.1538, F1 Score: 0.2322
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.00      0.00      0.00        18
#        _char       0.00      0.00      0.00         1
#     _country       0.00      0.00      0.00        23
#    _director       0.00      0.00      0.00        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.00      0.00      0.00        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.47      0.32      0.38       217
# _mpaa_rating       0.00      0.00      0.00        32
#      _person       0.00      0.00      0.00        39
#    _producer       0.00      0.00      0.00        38
#     _subject       0.00      0.00      0.00        21
#
#    micro avg       0.47      0.15      0.23       455
#    macro avg       0.04      0.03      0.03       455
# weighted avg       0.23      0.15      0.18       455
#
# Epoch 6/500, Train Loss: 0.0407, Test Loss: 0.0367
# Test Loss: 0.0329
# Precision: 0.5842, Recall: 0.2440, F1 Score: 0.3442
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.00      0.00      0.00        18
#        _char       0.00      0.00      0.00         1
#     _country       0.00      0.00      0.00        23
#    _director       0.50      0.06      0.11        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.00      0.00      0.00        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.59      0.50      0.54       217
# _mpaa_rating       0.00      0.00      0.00        32
#      _person       0.00      0.00      0.00        39
#    _producer       0.00      0.00      0.00        38
#     _subject       0.00      0.00      0.00        21
#
#    micro avg       0.58      0.24      0.34       455
#    macro avg       0.09      0.05      0.05       455
# weighted avg       0.32      0.24      0.27       455
#
# Epoch 7/500, Train Loss: 0.0363, Test Loss: 0.0329
# Test Loss: 0.0303
# Precision: 0.5708, Recall: 0.2923, F1 Score: 0.3866
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.00      0.00      0.00        18
#        _char       0.00      0.00      0.00         1
#     _country       0.00      0.00      0.00        23
#    _director       0.38      0.31      0.34        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.00      0.00      0.00        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.62      0.57      0.59       217
# _mpaa_rating       0.00      0.00      0.00        32
#      _person       0.00      0.00      0.00        39
#    _producer       0.00      0.00      0.00        38
#     _subject       0.00      0.00      0.00        21
#
#    micro avg       0.57      0.29      0.39       455
#    macro avg       0.08      0.07      0.08       455
# weighted avg       0.32      0.29      0.31       455
#
# Epoch 8/500, Train Loss: 0.0330, Test Loss: 0.0303
# Test Loss: 0.0287
# Precision: 0.5221, Recall: 0.2857, F1 Score: 0.3693
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.00      0.00      0.00        18
#        _char       0.00      0.00      0.00         1
#     _country       0.00      0.00      0.00        23
#    _director       0.29      0.38      0.33        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.00      0.00      0.00        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.62      0.54      0.57       217
# _mpaa_rating       0.00      0.00      0.00        32
#      _person       0.06      0.03      0.04        39
#    _producer       0.00      0.00      0.00        38
#     _subject       0.00      0.00      0.00        21
#
#    micro avg       0.52      0.29      0.37       455
#    macro avg       0.08      0.08      0.08       455
# weighted avg       0.32      0.29      0.30       455
#
# Epoch 9/500, Train Loss: 0.0303, Test Loss: 0.0287
# Test Loss: 0.0265
# Precision: 0.5049, Recall: 0.3407, F1 Score: 0.4068
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.00      0.00      0.00        18
#        _char       0.00      0.00      0.00         1
#     _country       0.00      0.00      0.00        23
#    _director       0.28      0.47      0.35        32
#       _genre       0.00      0.00      0.00        13
#    _language       1.00      0.20      0.33        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.64      0.61      0.62       217
# _mpaa_rating       0.50      0.03      0.06        32
#      _person       0.03      0.03      0.03        39
#    _producer       0.17      0.03      0.05        38
#     _subject       0.00      0.00      0.00        21
#
#    micro avg       0.50      0.34      0.41       455
#    macro avg       0.22      0.11      0.12       455
# weighted avg       0.42      0.34      0.35       455
#
# Epoch 10/500, Train Loss: 0.0281, Test Loss: 0.0265
# Test Loss: 0.0252
# Precision: 0.5382, Recall: 0.3560, F1 Score: 0.4286
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.00      0.00      0.00        18
#        _char       0.00      0.00      0.00         1
#     _country       1.00      0.13      0.23        23
#    _director       0.33      0.59      0.42        32
#       _genre       0.00      0.00      0.00        13
#    _language       1.00      0.30      0.46        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.65      0.59      0.62       217
# _mpaa_rating       0.50      0.03      0.06        32
#      _person       0.11      0.08      0.09        39
#    _producer       0.14      0.03      0.04        38
#     _subject       0.00      0.00      0.00        21
#
#    micro avg       0.54      0.36      0.43       455
#    macro avg       0.31      0.15      0.16       455
# weighted avg       0.49      0.36      0.37       455
#
# Epoch 11/500, Train Loss: 0.0260, Test Loss: 0.0252
# Test Loss: 0.0236
# Precision: 0.5593, Recall: 0.4044, F1 Score: 0.4694
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.00      0.00      0.00        18
#        _char       0.00      0.00      0.00         1
#     _country       1.00      0.26      0.41        23
#    _director       0.32      0.62      0.43        32
#       _genre       0.00      0.00      0.00        13
#    _language       1.00      0.45      0.62        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.66      0.63      0.64       217
# _mpaa_rating       0.71      0.16      0.26        32
#      _person       0.23      0.18      0.20        39
#    _producer       0.17      0.03      0.05        38
#     _subject       0.00      0.00      0.00        21
#
#    micro avg       0.56      0.40      0.47       455
#    macro avg       0.34      0.19      0.22       455
# weighted avg       0.52      0.40      0.42       455
#
# Epoch 12/500, Train Loss: 0.0243, Test Loss: 0.0236
# Test Loss: 0.0228
# Precision: 0.5507, Recall: 0.4176, F1 Score: 0.4750
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.00      0.00      0.00        18
#        _char       0.00      0.00      0.00         1
#     _country       0.90      0.39      0.55        23
#    _director       0.34      0.62      0.44        32
#       _genre       0.00      0.00      0.00        13
#    _language       1.00      0.55      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.67      0.62      0.64       217
# _mpaa_rating       0.80      0.25      0.38        32
#      _person       0.14      0.13      0.13        39
#    _producer       0.10      0.03      0.04        38
#     _subject       0.50      0.05      0.09        21
#
#    micro avg       0.55      0.42      0.47       455
#    macro avg       0.37      0.22      0.25       455
# weighted avg       0.53      0.42      0.44       455
#
# Epoch 13/500, Train Loss: 0.0225, Test Loss: 0.0228
# Test Loss: 0.0215
# Precision: 0.5764, Recall: 0.4725, F1 Score: 0.5193
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.22      0.11      0.15        18
#        _char       0.00      0.00      0.00         1
#     _country       0.79      0.48      0.59        23
#    _director       0.34      0.66      0.45        32
#       _genre       0.00      0.00      0.00        13
#    _language       1.00      0.55      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.65      0.65      0.65       217
# _mpaa_rating       0.77      0.31      0.44        32
#      _person       0.30      0.23      0.26        39
#    _producer       0.50      0.16      0.24        38
#     _subject       0.71      0.24      0.36        21
#
#    micro avg       0.58      0.47      0.52       455
#    macro avg       0.44      0.28      0.32       455
# weighted avg       0.58      0.47      0.50       455
#
# Epoch 14/500, Train Loss: 0.0212, Test Loss: 0.0215
# Test Loss: 0.0208
# Precision: 0.5935, Recall: 0.4813, F1 Score: 0.5316
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.22      0.11      0.15        18
#        _char       0.00      0.00      0.00         1
#     _country       0.82      0.39      0.53        23
#    _director       0.34      0.66      0.45        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.92      0.55      0.69        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.67      0.64      0.65       217
# _mpaa_rating       0.75      0.38      0.50        32
#      _person       0.41      0.31      0.35        39
#    _producer       0.46      0.16      0.24        38
#     _subject       0.70      0.33      0.45        21
#
#    micro avg       0.59      0.48      0.53       455
#    macro avg       0.44      0.29      0.33       455
# weighted avg       0.59      0.48      0.51       455
#
# Epoch 15/500, Train Loss: 0.0201, Test Loss: 0.0208
# Test Loss: 0.0200
# Precision: 0.6032, Recall: 0.4945, F1 Score: 0.5435
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.54      0.39      0.45        18
#        _char       0.00      0.00      0.00         1
#     _country       0.82      0.39      0.53        23
#    _director       0.37      0.66      0.47        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.85      0.55      0.67        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.67      0.64      0.66       217
# _mpaa_rating       0.81      0.41      0.54        32
#      _person       0.39      0.33      0.36        39
#    _producer       0.40      0.16      0.23        38
#     _subject       0.75      0.29      0.41        21
#
#    micro avg       0.60      0.49      0.54       455
#    macro avg       0.47      0.32      0.36       455
# weighted avg       0.60      0.49      0.53       455
#
# Epoch 16/500, Train Loss: 0.0188, Test Loss: 0.0200
# Test Loss: 0.0193
# Precision: 0.6019, Recall: 0.5648, F1 Score: 0.5828
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.57      0.44      0.50        18
#        _char       0.00      0.00      0.00         1
#     _country       0.73      0.70      0.71        23
#    _director       0.42      0.62      0.50        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.85      0.55      0.67        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.65      0.71      0.68       217
# _mpaa_rating       0.70      0.44      0.54        32
#      _person       0.40      0.41      0.41        39
#    _producer       0.48      0.32      0.38        38
#     _subject       0.70      0.33      0.45        21
#
#    micro avg       0.60      0.56      0.58       455
#    macro avg       0.46      0.38      0.40       455
# weighted avg       0.59      0.56      0.57       455
#
# Epoch 17/500, Train Loss: 0.0176, Test Loss: 0.0193
# Test Loss: 0.0188
# Precision: 0.6499, Recall: 0.5385, F1 Score: 0.5889
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.87      0.72      0.79        18
#        _char       0.00      0.00      0.00         1
#     _country       0.86      0.52      0.65        23
#    _director       0.46      0.69      0.55        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.92      0.55      0.69        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.68      0.65      0.67       217
# _mpaa_rating       0.82      0.44      0.57        32
#      _person       0.46      0.41      0.43        39
#    _producer       0.50      0.21      0.30        38
#     _subject       0.70      0.33      0.45        21
#
#    micro avg       0.65      0.54      0.59       455
#    macro avg       0.52      0.38      0.42       455
# weighted avg       0.64      0.54      0.57       455
#
# Epoch 18/500, Train Loss: 0.0169, Test Loss: 0.0188
# Test Loss: 0.0184
# Precision: 0.6649, Recall: 0.5582, F1 Score: 0.6069
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.81      0.72      0.76        18
#        _char       0.00      0.00      0.00         1
#     _country       0.69      0.48      0.56        23
#    _director       0.51      0.72      0.60        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.92      0.55      0.69        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.70      0.66      0.68       217
# _mpaa_rating       0.71      0.47      0.57        32
#      _person       0.53      0.49      0.51        39
#    _producer       0.58      0.29      0.39        38
#     _subject       0.70      0.33      0.45        21
#
#    micro avg       0.66      0.56      0.61       455
#    macro avg       0.51      0.39      0.43       455
# weighted avg       0.65      0.56      0.59       455
#
# Epoch 19/500, Train Loss: 0.0157, Test Loss: 0.0184
# Test Loss: 0.0183
# Precision: 0.6739, Recall: 0.5495, F1 Score: 0.6053
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.93      0.72      0.81        18
#        _char       0.00      0.00      0.00         1
#     _country       0.73      0.48      0.58        23
#    _director       0.53      0.72      0.61        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.92      0.55      0.69        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.69      0.65      0.67       217
# _mpaa_rating       0.78      0.44      0.56        32
#      _person       0.54      0.49      0.51        39
#    _producer       0.50      0.26      0.34        38
#     _subject       0.73      0.38      0.50        21
#
#    micro avg       0.67      0.55      0.61       455
#    macro avg       0.53      0.39      0.44       455
# weighted avg       0.66      0.55      0.59       455
#
# Epoch 20/500, Train Loss: 0.0150, Test Loss: 0.0183
# Test Loss: 0.0171
# Precision: 0.6698, Recall: 0.6242, F1 Score: 0.6462
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.76      0.72      0.74        18
#        _char       0.00      0.00      0.00         1
#     _country       0.70      0.70      0.70        23
#    _director       0.51      0.72      0.60        32
#       _genre       0.00      0.00      0.00        13
#    _language       0.86      0.60      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.70      0.73      0.71       217
# _mpaa_rating       0.70      0.50      0.58        32
#      _person       0.59      0.59      0.59        39
#    _producer       0.56      0.37      0.44        38
#     _subject       0.82      0.43      0.56        21
#
#    micro avg       0.67      0.62      0.65       455
#    macro avg       0.52      0.45      0.47       455
# weighted avg       0.66      0.62      0.63       455
#
# Epoch 21/500, Train Loss: 0.0141, Test Loss: 0.0171
# Test Loss: 0.0172
# Precision: 0.6765, Recall: 0.6066, F1 Score: 0.6396
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.76      0.72      0.74        18
#        _char       0.00      0.00      0.00         1
#     _country       0.73      0.70      0.71        23
#    _director       0.56      0.72      0.63        32
#       _genre       0.50      0.08      0.13        13
#    _language       0.86      0.60      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.70      0.68      0.69       217
# _mpaa_rating       0.71      0.53      0.61        32
#      _person       0.58      0.56      0.57        39
#    _producer       0.58      0.39      0.47        38
#     _subject       0.71      0.48      0.57        21
#
#    micro avg       0.68      0.61      0.64       455
#    macro avg       0.56      0.45      0.49       455
# weighted avg       0.67      0.61      0.63       455
#
# Epoch 22/500, Train Loss: 0.0132, Test Loss: 0.0172
# Test Loss: 0.0163
# Precision: 0.7000, Recall: 0.6308, F1 Score: 0.6636
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.72      0.72      0.72        18
#        _char       0.00      0.00      0.00         1
#     _country       0.77      0.74      0.76        23
#    _director       0.54      0.78      0.64        32
#       _genre       0.67      0.15      0.25        13
#    _language       0.86      0.60      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.73      0.71      0.71       217
# _mpaa_rating       0.77      0.53      0.63        32
#      _person       0.66      0.64      0.65        39
#    _producer       0.57      0.34      0.43        38
#     _subject       0.77      0.48      0.59        21
#
#    micro avg       0.70      0.63      0.66       455
#    macro avg       0.59      0.47      0.51       455
# weighted avg       0.70      0.63      0.65       455
#
# Epoch 23/500, Train Loss: 0.0123, Test Loss: 0.0163
# Test Loss: 0.0163
# Precision: 0.6930, Recall: 0.6352, F1 Score: 0.6628
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.72      0.72      0.72        18
#        _char       0.00      0.00      0.00         1
#     _country       0.68      0.74      0.71        23
#    _director       0.57      0.72      0.64        32
#       _genre       0.67      0.15      0.25        13
#    _language       0.86      0.60      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.71      0.70      0.70       217
# _mpaa_rating       0.82      0.56      0.67        32
#      _person       0.57      0.62      0.59        39
#    _producer       0.73      0.50      0.59        38
#     _subject       0.71      0.48      0.57        21
#
#    micro avg       0.69      0.64      0.66       455
#    macro avg       0.59      0.48      0.51       455
# weighted avg       0.70      0.64      0.66       455
#
# Epoch 24/500, Train Loss: 0.0119, Test Loss: 0.0163
# Test Loss: 0.0160
# Precision: 0.7041, Recall: 0.6484, F1 Score: 0.6751
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.78      0.78      0.78        18
#        _char       0.00      0.00      0.00         1
#     _country       0.71      0.74      0.72        23
#    _director       0.61      0.78      0.68        32
#       _genre       0.50      0.15      0.24        13
#    _language       0.86      0.60      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.71      0.73      0.72       217
# _mpaa_rating       0.79      0.47      0.59        32
#      _person       0.65      0.62      0.63        39
#    _producer       0.68      0.45      0.54        38
#     _subject       0.71      0.48      0.57        21
#
#    micro avg       0.70      0.65      0.68       455
#    macro avg       0.58      0.48      0.52       455
# weighted avg       0.70      0.65      0.66       455
#
# Epoch 25/500, Train Loss: 0.0114, Test Loss: 0.0160
# Test Loss: 0.0161
# Precision: 0.7054, Recall: 0.6264, F1 Score: 0.6636
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.82      0.78      0.80        18
#        _char       0.00      0.00      0.00         1
#     _country       0.76      0.70      0.73        23
#    _director       0.60      0.78      0.68        32
#       _genre       0.50      0.08      0.13        13
#    _language       0.86      0.60      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.72      0.69      0.70       217
# _mpaa_rating       0.70      0.50      0.58        32
#      _person       0.63      0.62      0.62        39
#    _producer       0.74      0.45      0.56        38
#     _subject       0.67      0.48      0.56        21
#
#    micro avg       0.71      0.63      0.66       455
#    macro avg       0.58      0.47      0.51       455
# weighted avg       0.70      0.63      0.65       455
#
# Epoch 26/500, Train Loss: 0.0107, Test Loss: 0.0161
# Test Loss: 0.0157
# Precision: 0.6865, Recall: 0.6352, F1 Score: 0.6598
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.78      0.78      0.78        18
#        _char       0.00      0.00      0.00         1
#     _country       0.67      0.70      0.68        23
#    _director       0.58      0.78      0.67        32
#       _genre       0.50      0.15      0.24        13
#    _language       0.86      0.60      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.70      0.69      0.70       217
# _mpaa_rating       0.79      0.59      0.68        32
#      _person       0.66      0.64      0.65        39
#    _producer       0.59      0.42      0.49        38
#     _subject       0.67      0.48      0.56        21
#
#    micro avg       0.69      0.64      0.66       455
#    macro avg       0.57      0.49      0.51       455
# weighted avg       0.68      0.64      0.65       455
#
# Epoch 27/500, Train Loss: 0.0102, Test Loss: 0.0157
# Test Loss: 0.0152
# Precision: 0.7087, Recall: 0.6791, F1 Score: 0.6936
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.78      0.78      0.78        18
#        _char       0.00      0.00      0.00         1
#     _country       0.74      0.74      0.74        23
#    _director       0.62      0.81      0.70        32
#       _genre       0.60      0.23      0.33        13
#    _language       0.86      0.60      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.72      0.74      0.73       217
# _mpaa_rating       0.83      0.59      0.69        32
#      _person       0.69      0.69      0.69        39
#    _producer       0.66      0.50      0.57        38
#     _subject       0.61      0.52      0.56        21
#
#    micro avg       0.71      0.68      0.69       455
#    macro avg       0.59      0.52      0.54       455
# weighted avg       0.71      0.68      0.69       455
#
# Epoch 28/500, Train Loss: 0.0098, Test Loss: 0.0152
# Test Loss: 0.0154
# Precision: 0.7093, Recall: 0.6703, F1 Score: 0.6893
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.78      0.78      0.78        18
#        _char       0.00      0.00      0.00         1
#     _country       0.67      0.78      0.72        23
#    _director       0.62      0.78      0.69        32
#       _genre       0.57      0.31      0.40        13
#    _language       0.86      0.60      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.73      0.71      0.72       217
# _mpaa_rating       0.77      0.62      0.69        32
#      _person       0.63      0.69      0.66        39
#    _producer       0.74      0.53      0.62        38
#     _subject       0.61      0.52      0.56        21
#
#    micro avg       0.71      0.67      0.69       455
#    macro avg       0.58      0.53      0.55       455
# weighted avg       0.71      0.67      0.68       455
#
# Epoch 29/500, Train Loss: 0.0093, Test Loss: 0.0154
# Test Loss: 0.0153
# Precision: 0.7077, Recall: 0.6703, F1 Score: 0.6885
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.82      0.78      0.80        18
#        _char       0.00      0.00      0.00         1
#     _country       0.69      0.78      0.73        23
#    _director       0.60      0.78      0.68        32
#       _genre       0.67      0.31      0.42        13
#    _language       0.86      0.60      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.72      0.71      0.72       217
# _mpaa_rating       0.71      0.62      0.67        32
#      _person       0.69      0.69      0.69        39
#    _producer       0.70      0.50      0.58        38
#     _subject       0.65      0.52      0.58        21
#
#    micro avg       0.71      0.67      0.69       455
#    macro avg       0.59      0.53      0.55       455
# weighted avg       0.71      0.67      0.68       455
#
# Epoch 30/500, Train Loss: 0.0091, Test Loss: 0.0153
# Test Loss: 0.0156
# Precision: 0.7205, Recall: 0.6571, F1 Score: 0.6874
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.78      0.78      0.78        18
#        _char       0.00      0.00      0.00         1
#     _country       0.74      0.74      0.74        23
#    _director       0.65      0.81      0.72        32
#       _genre       1.00      0.15      0.27        13
#    _language       0.86      0.60      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.73      0.70      0.71       217
# _mpaa_rating       0.82      0.56      0.67        32
#      _person       0.70      0.72      0.71        39
#    _producer       0.72      0.47      0.57        38
#     _subject       0.55      0.57      0.56        21
#
#    micro avg       0.72      0.66      0.69       455
#    macro avg       0.63      0.51      0.54       455
# weighted avg       0.73      0.66      0.68       455
#
# Epoch 31/500, Train Loss: 0.0084, Test Loss: 0.0156
# Test Loss: 0.0154
# Precision: 0.7109, Recall: 0.6593, F1 Score: 0.6842
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.79      0.83      0.81        18
#        _char       0.00      0.00      0.00         1
#     _country       0.80      0.70      0.74        23
#    _director       0.66      0.78      0.71        32
#       _genre       0.50      0.15      0.24        13
#    _language       0.82      0.70      0.76        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.71      0.70      0.70       217
# _mpaa_rating       0.79      0.59      0.68        32
#      _person       0.68      0.69      0.68        39
#    _producer       0.74      0.53      0.62        38
#     _subject       0.55      0.52      0.54        21
#
#    micro avg       0.71      0.66      0.68       455
#    macro avg       0.59      0.52      0.54       455
# weighted avg       0.71      0.66      0.68       455
#
# Epoch 32/500, Train Loss: 0.0080, Test Loss: 0.0154
# Test Loss: 0.0147
# Precision: 0.7127, Recall: 0.6923, F1 Score: 0.7023
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.78      0.78      0.78        18
#        _char       0.00      0.00      0.00         1
#     _country       0.72      0.78      0.75        23
#    _director       0.60      0.81      0.69        32
#       _genre       0.57      0.31      0.40        13
#    _language       0.80      0.60      0.69        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.73      0.74      0.74       217
# _mpaa_rating       0.78      0.66      0.71        32
#      _person       0.69      0.69      0.69        39
#    _producer       0.70      0.55      0.62        38
#     _subject       0.61      0.52      0.56        21
#
#    micro avg       0.71      0.69      0.70       455
#    macro avg       0.58      0.54      0.55       455
# weighted avg       0.71      0.69      0.70       455
#
# Epoch 33/500, Train Loss: 0.0074, Test Loss: 0.0147
# Test Loss: 0.0145
# Precision: 0.7133, Recall: 0.6945, F1 Score: 0.7038
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.78      0.78      0.78        18
#        _char       0.00      0.00      0.00         1
#     _country       0.65      0.74      0.69        23
#    _director       0.62      0.75      0.68        32
#       _genre       0.50      0.23      0.32        13
#    _language       0.86      0.60      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.73      0.76      0.75       217
# _mpaa_rating       0.77      0.62      0.69        32
#      _person       0.76      0.72      0.74        39
#    _producer       0.68      0.55      0.61        38
#     _subject       0.61      0.52      0.56        21
#
#    micro avg       0.71      0.69      0.70       455
#    macro avg       0.58      0.52      0.54       455
# weighted avg       0.71      0.69      0.70       455
#
# Epoch 34/500, Train Loss: 0.0071, Test Loss: 0.0145
# Test Loss: 0.0149
# Precision: 0.7333, Recall: 0.6769, F1 Score: 0.7040
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.78      0.78      0.78        18
#        _char       0.00      0.00      0.00         1
#     _country       0.74      0.74      0.74        23
#    _director       0.64      0.72      0.68        32
#       _genre       0.57      0.31      0.40        13
#    _language       0.81      0.65      0.72        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.74      0.73      0.73       217
# _mpaa_rating       0.79      0.59      0.68        32
#      _person       0.81      0.74      0.77        39
#    _producer       0.71      0.53      0.61        38
#     _subject       0.61      0.52      0.56        21
#
#    micro avg       0.73      0.68      0.70       455
#    macro avg       0.60      0.53      0.56       455
# weighted avg       0.73      0.68      0.70       455
#
# Epoch 35/500, Train Loss: 0.0067, Test Loss: 0.0149
# Test Loss: 0.0154
# Precision: 0.7035, Recall: 0.6571, F1 Score: 0.6795
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.79      0.83      0.81        18
#        _char       0.00      0.00      0.00         1
#     _country       0.73      0.70      0.71        23
#    _director       0.62      0.75      0.68        32
#       _genre       0.57      0.31      0.40        13
#    _language       0.76      0.65      0.70        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.70      0.68      0.69       217
# _mpaa_rating       0.84      0.66      0.74        32
#      _person       0.71      0.69      0.70        39
#    _producer       0.67      0.53      0.59        38
#     _subject       0.61      0.52      0.56        21
#
#    micro avg       0.70      0.66      0.68       455
#    macro avg       0.58      0.53      0.55       455
# weighted avg       0.70      0.66      0.68       455
#
# Epoch 36/500, Train Loss: 0.0068, Test Loss: 0.0154
# Test Loss: 0.0157
# Precision: 0.7043, Recall: 0.6440, F1 Score: 0.6728
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.75      0.83      0.79        18
#        _char       0.00      0.00      0.00         1
#     _country       0.75      0.65      0.70        23
#    _director       0.57      0.75      0.65        32
#       _genre       0.67      0.31      0.42        13
#    _language       0.76      0.65      0.70        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.72      0.68      0.70       217
# _mpaa_rating       0.83      0.59      0.69        32
#      _person       0.62      0.62      0.62        39
#    _producer       0.78      0.55      0.65        38
#     _subject       0.61      0.52      0.56        21
#
#    micro avg       0.70      0.64      0.67       455
#    macro avg       0.59      0.51      0.54       455
# weighted avg       0.71      0.64      0.67       455
#
# Epoch 37/500, Train Loss: 0.0063, Test Loss: 0.0157
# Test Loss: 0.0154
# Precision: 0.7160, Recall: 0.6593, F1 Score: 0.6865
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.74      0.78      0.76        18
#        _char       0.00      0.00      0.00         1
#     _country       0.74      0.74      0.74        23
#    _director       0.68      0.78      0.72        32
#       _genre       0.57      0.31      0.40        13
#    _language       0.86      0.60      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.72      0.71      0.71       217
# _mpaa_rating       0.83      0.59      0.69        32
#      _person       0.65      0.62      0.63        39
#    _producer       0.72      0.55      0.63        38
#     _subject       0.61      0.52      0.56        21
#
#    micro avg       0.72      0.66      0.69       455
#    macro avg       0.59      0.52      0.55       455
# weighted avg       0.71      0.66      0.68       455
#
# Epoch 38/500, Train Loss: 0.0061, Test Loss: 0.0154
# Test Loss: 0.0148
# Precision: 0.7285, Recall: 0.6901, F1 Score: 0.7088
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.83      0.83      0.83        18
#        _char       0.00      0.00      0.00         1
#     _country       0.75      0.78      0.77        23
#    _director       0.64      0.78      0.70        32
#       _genre       0.40      0.15      0.22        13
#    _language       0.88      0.70      0.78        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.74      0.73      0.73       217
# _mpaa_rating       0.77      0.62      0.69        32
#      _person       0.72      0.74      0.73        39
#    _producer       0.76      0.58      0.66        38
#     _subject       0.55      0.52      0.54        21
#
#    micro avg       0.73      0.69      0.71       455
#    macro avg       0.59      0.54      0.55       455
# weighted avg       0.72      0.69      0.70       455
#
# Epoch 39/500, Train Loss: 0.0059, Test Loss: 0.0148
# Test Loss: 0.0148
# Precision: 0.7192, Recall: 0.6923, F1 Score: 0.7055
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.88      0.83      0.86        18
#        _char       1.00      1.00      1.00         1
#     _country       0.82      0.78      0.80        23
#    _director       0.63      0.75      0.69        32
#       _genre       0.57      0.31      0.40        13
#    _language       0.68      0.65      0.67        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.72      0.73      0.72       217
# _mpaa_rating       0.78      0.66      0.71        32
#      _person       0.76      0.72      0.74        39
#    _producer       0.70      0.55      0.62        38
#     _subject       0.61      0.52      0.56        21
#
#    micro avg       0.72      0.69      0.71       455
#    macro avg       0.68      0.63      0.65       455
# weighted avg       0.72      0.69      0.70       455
#
# Epoch 40/500, Train Loss: 0.0056, Test Loss: 0.0148
# Test Loss: 0.0153
# Precision: 0.7136, Recall: 0.6681, F1 Score: 0.6901
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.78      0.78      0.78        18
#        _char       0.00      0.00      0.00         1
#     _country       0.71      0.74      0.72        23
#    _director       0.56      0.72      0.63        32
#       _genre       0.67      0.31      0.42        13
#    _language       0.87      0.65      0.74        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.72      0.71      0.71       217
# _mpaa_rating       0.75      0.66      0.70        32
#      _person       0.74      0.64      0.68        39
#    _producer       0.73      0.58      0.65        38
#     _subject       0.69      0.52      0.59        21
#
#    micro avg       0.71      0.67      0.69       455
#    macro avg       0.60      0.53      0.55       455
# weighted avg       0.72      0.67      0.69       455
#
# Epoch 41/500, Train Loss: 0.0054, Test Loss: 0.0153
# Test Loss: 0.0151
# Precision: 0.7233, Recall: 0.6835, F1 Score: 0.7028
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.78      0.78      0.78        18
#        _char       0.00      0.00      0.00         1
#     _country       0.73      0.70      0.71        23
#    _director       0.57      0.72      0.64        32
#       _genre       0.57      0.31      0.40        13
#    _language       0.82      0.70      0.76        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.73      0.73      0.73       217
# _mpaa_rating       0.80      0.62      0.70        32
#      _person       0.77      0.69      0.73        39
#    _producer       0.74      0.61      0.67        38
#     _subject       0.61      0.52      0.56        21
#
#    micro avg       0.72      0.68      0.70       455
#    macro avg       0.59      0.53      0.56       455
# weighted avg       0.72      0.68      0.70       455
#
# Epoch 42/500, Train Loss: 0.0052, Test Loss: 0.0151
# Test Loss: 0.0148
# Precision: 0.7143, Recall: 0.7143, F1 Score: 0.7143
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.83      0.83      0.83        18
#        _char       1.00      1.00      1.00         1
#     _country       0.67      0.78      0.72        23
#    _director       0.63      0.75      0.69        32
#       _genre       0.56      0.38      0.45        13
#    _language       0.81      0.65      0.72        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.73      0.76      0.74       217
# _mpaa_rating       0.76      0.69      0.72        32
#      _person       0.74      0.72      0.73        39
#    _producer       0.70      0.61      0.65        38
#     _subject       0.58      0.52      0.55        21
#
#    micro avg       0.71      0.71      0.71       455
#    macro avg       0.67      0.64      0.65       455
# weighted avg       0.71      0.71      0.71       455
#
# Epoch 43/500, Train Loss: 0.0047, Test Loss: 0.0148
# Test Loss: 0.0153
# Precision: 0.7311, Recall: 0.6813, F1 Score: 0.7053
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.74      0.78      0.76        18
#        _char       0.00      0.00      0.00         1
#     _country       0.72      0.78      0.75        23
#    _director       0.62      0.72      0.67        32
#       _genre       0.50      0.31      0.38        13
#    _language       0.87      0.65      0.74        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.74      0.72      0.73       217
# _mpaa_rating       0.79      0.59      0.68        32
#      _person       0.76      0.74      0.75        39
#    _producer       0.76      0.58      0.66        38
#     _subject       0.65      0.52      0.58        21
#
#    micro avg       0.73      0.68      0.71       455
#    macro avg       0.60      0.53      0.56       455
# weighted avg       0.73      0.68      0.70       455
#
# Epoch 44/500, Train Loss: 0.0048, Test Loss: 0.0153
# Test Loss: 0.0153
# Precision: 0.7368, Recall: 0.7077, F1 Score: 0.7220
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.74      0.78      0.76        18
#        _char       0.00      0.00      0.00         1
#     _country       0.86      0.83      0.84        23
#    _director       0.62      0.75      0.68        32
#       _genre       0.57      0.31      0.40        13
#    _language       0.74      0.70      0.72        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.75      0.76      0.75       217
# _mpaa_rating       0.81      0.66      0.72        32
#      _person       0.81      0.74      0.77        39
#    _producer       0.70      0.55      0.62        38
# ...
# weighted avg       0.76      0.73      0.74       455
#
# Epoch 485/500, Train Loss: 0.0001, Test Loss: 0.0352
# Test Loss: 0.0354
# Precision: 0.7529, Recall: 0.7231, F1 Score: 0.7377
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.71      0.83      0.77        18
#        _char       1.00      1.00      1.00         1
#     _country       0.86      0.83      0.84        23
#    _director       0.65      0.75      0.70        32
#       _genre       0.62      0.38      0.48        13
#    _language       0.65      0.75      0.70        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.75      0.75      0.75       217
# _mpaa_rating       0.89      0.78      0.83        32
#      _person       0.84      0.67      0.74        39
#    _producer       0.75      0.63      0.69        38
#     _subject       0.75      0.57      0.65        21
#        movie       0.00      0.00      0.00         0
#
#    micro avg       0.75      0.72      0.74       455
#    macro avg       0.65      0.61      0.63       455
# weighted avg       0.76      0.72      0.74       455
#
# Epoch 486/500, Train Loss: 0.0002, Test Loss: 0.0354
# Test Loss: 0.0332
# Precision: 0.7618, Recall: 0.7451, F1 Score: 0.7533
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.84      0.89      0.86        18
#        _char       1.00      1.00      1.00         1
#     _country       0.83      0.87      0.85        23
#    _director       0.63      0.81      0.71        32
#       _genre       0.57      0.31      0.40        13
#    _language       0.85      0.85      0.85        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.78      0.77      0.78       217
# _mpaa_rating       0.83      0.78      0.81        32
#      _person       0.76      0.72      0.74        39
#    _producer       0.73      0.58      0.65        38
#     _subject       0.63      0.57      0.60        21
#        movie       0.00      0.00      0.00         0
#
#    micro avg       0.76      0.75      0.75       455
#    macro avg       0.65      0.63      0.63       455
# weighted avg       0.76      0.75      0.75       455
#
# Epoch 487/500, Train Loss: 0.0002, Test Loss: 0.0332
# Test Loss: 0.0350
# Precision: 0.7376, Recall: 0.7165, F1 Score: 0.7269
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.80      0.89      0.84        18
#        _char       1.00      1.00      1.00         1
#     _country       0.86      0.78      0.82        23
#    _director       0.59      0.72      0.65        32
#       _genre       0.67      0.31      0.42        13
#    _language       0.65      0.75      0.70        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.76      0.75      0.75       217
# _mpaa_rating       0.86      0.75      0.80        32
#      _person       0.70      0.72      0.71        39
#    _producer       0.70      0.61      0.65        38
#     _subject       0.73      0.52      0.61        21
#        movie       0.00      0.00      0.00         0
#
#    micro avg       0.74      0.72      0.73       455
#    macro avg       0.64      0.60      0.61       455
# weighted avg       0.74      0.72      0.72       455
#
# Epoch 488/500, Train Loss: 0.0001, Test Loss: 0.0350
# Test Loss: 0.0345
# Precision: 0.7535, Recall: 0.7187, F1 Score: 0.7357
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.75      0.83      0.79        18
#        _char       1.00      1.00      1.00         1
#     _country       0.86      0.83      0.84        23
#    _director       0.57      0.75      0.65        32
#       _genre       0.57      0.31      0.40        13
#    _language       0.79      0.75      0.77        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.77      0.76      0.76       217
# _mpaa_rating       0.89      0.75      0.81        32
#      _person       0.78      0.72      0.75        39
#    _producer       0.73      0.58      0.65        38
#     _subject       0.65      0.52      0.58        21
#        movie       0.00      0.00      0.00         0
#
#    micro avg       0.75      0.72      0.74       455
#    macro avg       0.64      0.60      0.62       455
# weighted avg       0.76      0.72      0.73       455
#
# Epoch 489/500, Train Loss: 0.0001, Test Loss: 0.0345
# Test Loss: 0.0356
# Precision: 0.7640, Recall: 0.7187, F1 Score: 0.7407
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.76      0.89      0.82        18
#        _char       1.00      1.00      1.00         1
#     _country       0.83      0.87      0.85        23
#    _director       0.63      0.75      0.69        32
#       _genre       0.57      0.31      0.40        13
#    _language       0.79      0.75      0.77        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.78      0.75      0.76       217
# _mpaa_rating       1.00      0.75      0.86        32
#      _person       0.79      0.67      0.72        39
#    _producer       0.69      0.63      0.66        38
#     _subject       0.65      0.52      0.58        21
#        movie       0.00      0.00      0.00         0
#
#    micro avg       0.76      0.72      0.74       455
#    macro avg       0.65      0.61      0.62       455
# weighted avg       0.77      0.72      0.74       455
#
# Epoch 490/500, Train Loss: 0.0001, Test Loss: 0.0356
# Test Loss: 0.0378
# Precision: 0.7488, Recall: 0.7011, F1 Score: 0.7242
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.71      0.83      0.77        18
#        _char       1.00      1.00      1.00         1
#     _country       0.91      0.87      0.89        23
#    _director       0.62      0.72      0.67        32
#       _genre       0.62      0.38      0.48        13
#    _language       0.71      0.75      0.73        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.78      0.71      0.74       217
# _mpaa_rating       0.86      0.75      0.80        32
#      _person       0.74      0.72      0.73        39
#    _producer       0.70      0.61      0.65        38
#     _subject       0.58      0.52      0.55        21
#
#    micro avg       0.75      0.70      0.72       455
#    macro avg       0.69      0.66      0.67       455
# weighted avg       0.75      0.70      0.72       455
#
# Epoch 491/500, Train Loss: 0.0001, Test Loss: 0.0378
# Test Loss: 0.0329
# Precision: 0.7333, Recall: 0.7253, F1 Score: 0.7293
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.73      0.89      0.80        18
#        _char       1.00      1.00      1.00         1
#     _country       0.83      0.83      0.83        23
#    _director       0.63      0.69      0.66        32
#       _genre       0.67      0.46      0.55        13
#    _language       0.75      0.75      0.75        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.73      0.74      0.74       217
# _mpaa_rating       0.90      0.84      0.87        32
#      _person       0.73      0.77      0.75        39
#    _producer       0.73      0.58      0.65        38
#     _subject       0.65      0.52      0.58        21
#        movie       0.00      0.00      0.00         0
#
#    micro avg       0.73      0.73      0.73       455
#    macro avg       0.64      0.62      0.63       455
# weighted avg       0.73      0.73      0.73       455
#
# Epoch 492/500, Train Loss: 0.0001, Test Loss: 0.0329
# Test Loss: 0.0343
# Precision: 0.7546, Recall: 0.7165, F1 Score: 0.7351
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.76      0.89      0.82        18
#        _char       1.00      1.00      1.00         1
#     _country       0.90      0.83      0.86        23
#    _director       0.59      0.72      0.65        32
#       _genre       0.80      0.31      0.44        13
#    _language       0.75      0.75      0.75        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.75      0.75      0.75       217
# _mpaa_rating       0.96      0.75      0.84        32
#      _person       0.82      0.72      0.77        39
#    _producer       0.71      0.58      0.64        38
#     _subject       0.60      0.57      0.59        21
#
#    micro avg       0.75      0.72      0.74       455
#    macro avg       0.72      0.65      0.68       455
# weighted avg       0.76      0.72      0.73       455
#
# Epoch 493/500, Train Loss: 0.0002, Test Loss: 0.0343
# Test Loss: 0.0318
# Precision: 0.7320, Recall: 0.7385, F1 Score: 0.7352
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.79      0.83      0.81        18
#        _char       1.00      1.00      1.00         1
#     _country       0.84      0.70      0.76        23
#    _director       0.65      0.88      0.75        32
#       _genre       0.67      0.31      0.42        13
#    _language       0.58      0.75      0.65        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.74      0.78      0.76       217
# _mpaa_rating       0.93      0.78      0.85        32
#      _person       0.78      0.72      0.75        39
#    _producer       0.71      0.58      0.64        38
#     _subject       0.57      0.57      0.57        21
#        movie       0.00      0.00      0.00         0
#
#    micro avg       0.73      0.74      0.74       455
#    macro avg       0.63      0.61      0.61       455
# weighted avg       0.74      0.74      0.73       455
#
# Epoch 494/500, Train Loss: 0.0002, Test Loss: 0.0318
# Test Loss: 0.0345
# Precision: 0.7540, Recall: 0.7275, F1 Score: 0.7405
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.80      0.89      0.84        18
#        _char       1.00      1.00      1.00         1
#     _country       0.83      0.87      0.85        23
#    _director       0.63      0.75      0.69        32
#       _genre       0.50      0.38      0.43        13
#    _language       0.70      0.70      0.70        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.76      0.76      0.76       217
# _mpaa_rating       0.96      0.75      0.84        32
#      _person       0.77      0.69      0.73        39
#    _producer       0.74      0.66      0.69        38
#     _subject       0.65      0.52      0.58        21
#
#    micro avg       0.75      0.73      0.74       455
#    macro avg       0.70      0.66      0.68       455
# weighted avg       0.75      0.73      0.74       455
#
# Epoch 495/500, Train Loss: 0.0001, Test Loss: 0.0345
# Test Loss: 0.0335
# Precision: 0.7545, Recall: 0.7363, F1 Score: 0.7453
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.80      0.89      0.84        18
#        _char       1.00      1.00      1.00         1
#     _country       0.87      0.87      0.87        23
#    _director       0.73      0.75      0.74        32
#       _genre       0.83      0.38      0.53        13
#    _language       0.68      0.75      0.71        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.76      0.75      0.75       217
# _mpaa_rating       0.93      0.81      0.87        32
#      _person       0.72      0.74      0.73        39
#    _producer       0.69      0.66      0.68        38
#     _subject       0.60      0.57      0.59        21
#        movie       0.00      0.00      0.00         0
#
#    micro avg       0.75      0.74      0.75       455
#    macro avg       0.66      0.63      0.64       455
# weighted avg       0.76      0.74      0.74       455
#
# Epoch 496/500, Train Loss: 0.0001, Test Loss: 0.0335
# Test Loss: 0.0360
# Precision: 0.7432, Recall: 0.7187, F1 Score: 0.7307
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.80      0.89      0.84        18
#        _char       1.00      1.00      1.00         1
#     _country       0.83      0.87      0.85        23
#    _director       0.63      0.75      0.69        32
#       _genre       0.62      0.38      0.48        13
#    _language       0.71      0.75      0.73        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.75      0.73      0.74       217
# _mpaa_rating       0.96      0.75      0.84        32
#      _person       0.71      0.74      0.72        39
#    _producer       0.74      0.61      0.67        38
#     _subject       0.63      0.57      0.60        21
#        movie       0.00      0.00      0.00         0
#
#    micro avg       0.74      0.72      0.73       455
#    macro avg       0.65      0.62      0.63       455
# weighted avg       0.75      0.72      0.73       455
#
# Epoch 497/500, Train Loss: 0.0001, Test Loss: 0.0360
# Test Loss: 0.0354
# Precision: 0.7517, Recall: 0.7253, F1 Score: 0.7383
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.80      0.89      0.84        18
#        _char       1.00      1.00      1.00         1
#     _country       0.83      0.87      0.85        23
#    _director       0.73      0.69      0.71        32
#       _genre       0.62      0.38      0.48        13
#    _language       0.71      0.75      0.73        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.75      0.74      0.75       217
# _mpaa_rating       0.96      0.72      0.82        32
#      _person       0.72      0.79      0.76        39
#    _producer       0.73      0.63      0.68        38
#     _subject       0.63      0.57      0.60        21
#        movie       0.00      0.00      0.00         0
#
#    micro avg       0.75      0.73      0.74       455
#    macro avg       0.65      0.62      0.63       455
# weighted avg       0.75      0.73      0.74       455
#
# Epoch 498/500, Train Loss: 0.0001, Test Loss: 0.0354
# Test Loss: 0.0334
# Precision: 0.7461, Recall: 0.7363, F1 Score: 0.7412
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.76      0.89      0.82        18
#        _char       1.00      1.00      1.00         1
#     _country       0.87      0.87      0.87        23
#    _director       0.62      0.78      0.69        32
#       _genre       0.71      0.38      0.50        13
#    _language       0.81      0.85      0.83        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.75      0.74      0.74       217
# _mpaa_rating       0.90      0.84      0.87        32
#      _person       0.74      0.72      0.73        39
#    _producer       0.71      0.63      0.67        38
#     _subject       0.65      0.52      0.58        21
#        movie       0.00      0.00      0.00         0
#
#    micro avg       0.75      0.74      0.74       455
#    macro avg       0.66      0.63      0.64       455
# weighted avg       0.75      0.74      0.74       455
#
# Epoch 499/500, Train Loss: 0.0001, Test Loss: 0.0334
# Test Loss: 0.0357
# Precision: 0.7546, Recall: 0.7231, F1 Score: 0.7385
# Classification Report:
#                precision    recall  f1-score   support
#
#        _cast       0.73      0.89      0.80        18
#        _char       1.00      1.00      1.00         1
#     _country       0.87      0.87      0.87        23
#    _director       0.66      0.78      0.71        32
#       _genre       0.50      0.23      0.32        13
#    _language       0.81      0.85      0.83        20
#    _location       0.00      0.00      0.00         1
#       _movie       0.76      0.74      0.75       217
# _mpaa_rating       0.96      0.72      0.82        32
#      _person       0.76      0.72      0.74        39
#    _producer       0.73      0.63      0.68        38
#     _subject       0.60      0.57      0.59        21
#        movie       0.00      0.00      0.00         0
#
#    micro avg       0.75      0.72      0.74       455
#    macro avg       0.64      0.62      0.62       455
# weighted avg       0.76      0.72      0.74       455
#
# Epoch 500/500, Train Loss: 0.0001, Test Loss: 0.0357

# %%
# 載入測試數據
test_df = pd.read_csv('hw2_test.csv')

# 定義生成提交文件的函數
def generate_submission_file(model, test_df, tokenizer, bert_model, idx_to_label, device, output_file="submission_500.csv"):
    model.eval()
    predictions = []

    with torch.no_grad():
        for idx, row in test_df.iterrows():
            utterance = row["utterances"]
            
            # 1. 使用 BERT 將句子轉換為嵌入
            inputs = tokenizer(utterance, padding="max_length", truncation=True, max_length=128, return_tensors="pt").to(device)
            embeddings = bert_model(**inputs).last_hidden_state  # 取得 BERT 最後一層的輸出 (batch_size, seq_len, hidden_dim)
            
            # 2. 使用模型進行預測
            outputs = model(embeddings)  # 確認這裡的輸出是 (batch_size, seq_len, output_dim)
            
            # 3. 確保 outputs 的維度符合預期
            if outputs.dim() == 2:  # 當輸出只有 (seq_len, output_dim) 時進行擴展
                outputs = outputs.unsqueeze(0)  # 增加 batch 維度

            # 4. 獲取每個位置的預測標籤
            pred_labels = torch.argmax(outputs, dim=2).squeeze().cpu().numpy()
            pred_labels = [idx_to_label[label] for label in pred_labels[:len(inputs['input_ids'][0])]]

            # 5. 將子詞標籤整合成單詞標籤
            tokens = tokenizer.tokenize(utterance)
            final_labels = []
            token_idx = 0

            for label in pred_labels:
                if token_idx >= len(tokens):
                    break  # 防止 token_idx 超出 tokens 的長度
                
                # 跳過以 "##" 開頭的子詞標籤
                if tokens[token_idx].startswith("##"):
                    token_idx += 1
                    continue
                
                final_labels.append(label)
                token_idx += 1

            # 6. 加入預測結果
            predictions.append(" ".join(final_labels))

    # 建立提交文件格式
    submission_df = pd.DataFrame({"ID": test_df["ID"], "IOB Slot tags": predictions})
    submission_df.to_csv(output_file, index=False)
    print(f"提交文件已生成：{output_file}")

# 構建標籤映射字典
unique_labels = set(label for tags in train_df['IOB Slot tags'] for label in tags.split())
label_to_index = {label: idx for idx, label in enumerate(unique_labels)}
idx_to_label = {idx: label for label, idx in label_to_index.items()}

# 生成提交文件
generate_submission_file(model, test_df, tokenizer, bert_model, idx_to_label, device)
# Out:
# 提交文件已生成：submission_500.csv
